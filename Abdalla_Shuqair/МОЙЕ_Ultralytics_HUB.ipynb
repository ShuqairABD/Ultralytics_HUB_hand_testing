# %% [markdown]
# <a href="https://colab.research.google.com/github/ShuqairABD/Ultralytics_HUB_hand_testing/blob/main/Abdalla_Shuqair/%D0%9C%D0%9E%D0%99%D0%95_Ultralytics_HUB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Start**

# %%
# %pip install ultralytics
from ultralytics import YOLO, checks, hub

checks()
# Out:
# Ultralytics YOLOv8.2.95 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.6/235.7 GB disk)

# %%
hub.login('8a16c144be7c60c64fd155a9401ff0bf16abb49ce6')

model = YOLO('https://hub.ultralytics.com/models/VEu7VGGOphNnWlsu90pn')
results = model.train()
# Out:
# requirements: Ultralytics requirement ['hub-sdk>=0.0.8'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 kB 2.8 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 3.0s, installed 1 package: ['hub-sdk>=0.0.8']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Ultralytics HUB: New authentication successful ✅
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/VEu7VGGOphNnWlsu90pn 🚀
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 171MB/s]
# Ultralytics YOLOv8.2.95 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from IPython import display
from IPython.display import display, Image
import os

# %%
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=900)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/confusion_matrix_normalized.png', width=900)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/results.png', width=900)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/train_batch2521.jpg', width=900)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=900)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/R_curve.png', width=900)
# Out:
# /content

# %% [markdown]
# (https://hub.ultralytics.com/settings?tab=api+keys)
